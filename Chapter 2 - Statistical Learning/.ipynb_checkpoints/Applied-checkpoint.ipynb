# %% [markdown]
# # 8. This exercise relates to the College data set, which can be found in the file College.csv on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are
# Variable Name|Description
# :-:|:-:
# Private|Public/private indicator
# Apps|Number of applications received
# Accept|Number of applicants accepted
# Enroll|Number of new students enrolled
# Top10perc|New students from top 10 % of high school class
# Top25perc|New students from top 25 % of high school class
# F.Undergrad|Number of full-time undergraduates
# P.Undergrad|Number of part-time undergraduates
# Outstate|Out-of-state tuition
# Room.Board|Room and board costs
# Books|Estimated book costs
# Personal|Estimated personal spending
# PhD|Percent of faculty with Ph.D.s
# Terminal|Percent of faculty with terminal degree
# S.F.Ratio|Student/faculty ratio
# perc.alumni|Percent of alumni who donate
# Expend|Instructional expenditure per student
# Grad.Rate|Graduation rate
# Before reading the data into Python, it can be viewed in Excel or a text editor.

# %% [markdown]
# ### (a) Use the pd.read_csv() function to read the data into Python. Call the loaded data college. Make sure that you have the directory set to the correct location for the data.

# %%
import pandas as pd 
import numpy as np 

college = pd.read_csv(r"../Datasets/College.csv")

# %% [markdown]
# ### (b) Look at the data used in the notebook by creating and running a new cell with just the code college in it. You should notice that the first column is just the name of each university in a column named something like Unnamed: 0. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later. Try the following commands and similarly look at the resulting data frames:
# ```
# college2 = pd.read_csv('College.csv', index_col=0)
# college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
# college3 = college3.set_index('College')
# ```
# ### This has used the first column in the file as an index for the data frame. This means that pandas has given each row a name corresponding to the appropriate university. Now you should see that the first data column is Private. Note that the names of the colleges appear on the left of the table. We also introduced a new python object above: a dictionary, which is specified by dictionary (key, value) pairs. Keep your modified version of the data with the following:
# ```
# college = college3
# ```

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv(r'../Datasets/College.csv', index_col=0)
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
college3 = college3.set_index('College')
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college = college3

# %% [markdown]
# ### (c) Use the describe() method to produce a numerical summary of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### (d) Use the pd.plotting.scatter_matrix() function to produce a scatterplot matrix of the first columns [Top10perc, Apps, Enroll]. Recall that you can reference a list C of columns of a data frame A using A[C].

# %%
pd.plotting.scatter_matrix(college[['Top10perc','Apps','Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# ### (e) Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private

# %%
college.boxplot(column='Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# ### (f) Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.
# ```
# college['Elite'] = pd.cut(college['Top10perc'], [0,0.5,1], labels=['No', 'Yes'])
# ```
# ### Use the value_counts() method of college['Elite'] to see how many elite universities there are. Finally, use the boxplot() method again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college['RatioTop10'] = college.Top10perc/college.Enroll
college['Elite'] = pd.cut(x=college['RatioTop10'], bins=[0,0.5,1], labels = ['No','Yes'])

# %%
college.Elite.value_counts()
# Out:
# No     775
# Yes      2
# Name: Elite, dtype: int64

# %%
college.boxplot(column='Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# ### (g) Use the plot.hist() method of college to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2,2)

college.Apps.plot.hist(ax=axes[0, 0], bins=10)
college.Accept.plot.hist(ax=axes[0, 1], bins=5)
college.Enroll.plot.hist(ax=axes[1, 0], bins=7)
college.Expend.plot.hist(ax=axes[1, 1])

axes[0, 0].set_title('Apps')
axes[0, 1].set_title('Accept')
axes[1, 0].set_title('Enroll')
axes[1, 1].set_title('Expend')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### (h) Continue exploring the data, and provide a brief summary of what you discover.

# %%
college.isna().sum()
# Out:
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# RatioTop10     0
# Elite          0
# dtype: int64

# %%
plt.figure(figsize=(20,15))
college.hist()
plt.tight_layout()

# %%
import seaborn as sns
sns.heatmap(college.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# - Data has no null values
# - Most features are right skewed

# %% [markdown]
# # 9. This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %% [markdown]
# ### (a) Which of the predictors are quantitative, and which are qualitative?

# %%
auto = pd.read_csv(r"../Datasets/Auto.csv")

# %%
auto.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
auto.select_dtypes('number').columns.tolist()
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'weight',
#  'acceleration',
#  'year',
#  'origin']

# %%
auto.select_dtypes('object').columns.tolist()
# Out:
# ['horsepower', 'name']

# %% [markdown]
# ### (b) What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.

# %%
auto.max(numeric_only=True) - auto.min(numeric_only=True)
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# origin             2.0
# dtype: float64

# %% [markdown]
# ### (c) What is the mean and standard deviation of each quantitative predictor?

# %%
auto.mean(numeric_only=True)
# Out:
# mpg               23.515869
# cylinders          5.458438
# displacement     193.532746
# weight          2970.261965
# acceleration      15.555668
# year              75.994962
# origin             1.574307
# dtype: float64

# %%
auto.std(numeric_only=True)
# Out:
# mpg               7.825804
# cylinders         1.701577
# displacement    104.379583
# weight          847.904119
# acceleration      2.749995
# year              3.690005
# origin            0.802549
# dtype: float64

# %% [markdown]
# ### (d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
auto2 = auto.drop(index=[i for i in range(9,85)])
auto2.max(numeric_only=True) - auto2.min(numeric_only=True)
# Out:
# mpg               35.6
# cylinders          5.0
# displacement     387.0
# weight          3348.0
# acceleration      16.3
# year              12.0
# origin             2.0
# dtype: float64

# %%
auto2.mean(numeric_only=True)
# Out:
# mpg               24.438629
# cylinders          5.370717
# displacement     187.049844
# weight          2933.962617
# acceleration      15.723053
# year              77.152648
# origin             1.598131
# dtype: float64

# %%
auto2.std(numeric_only=True)
# Out:
# mpg               7.908184
# cylinders         1.653486
# displacement     99.635385
# weight          810.642938
# acceleration      2.680514
# year              3.111230
# origin            0.816163
# dtype: float64

# %% [markdown]
# ### (e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
auto.select_dtypes('number').hist()
plt.tight_layout()

# %%
fig, axes = plt.subplots(1,7, figsize = (12, 6))
auto[['mpg']].boxplot(ax = axes[0])
auto[['cylinders']].boxplot(ax = axes[1])
auto[['displacement']].boxplot(ax = axes[2])
auto[['weight']].boxplot(ax = axes[3])
auto[['acceleration']].boxplot(ax = axes[4])
auto[['year']].boxplot(ax = axes[5])
auto[['origin']].boxplot(ax = axes[6])
plt.tight_layout()

# %%
plt.figure(figsize=(6, 16))
plt.barh(auto.horsepower.value_counts().index, auto.horsepower.value_counts().values)
# Out:
# <BarContainer object of 94 artists>

# %%
pd.plotting.scatter_matrix(auto, figsize=(16,16))
plt.tight_layout()

# %%
sns.heatmap(auto.corr(numeric_only=True), annot=True, cmap='RdBu')
# Out:
# <Axes: >

# %%
for feature_name in auto.columns.tolist():
    print(auto[feature_name].value_counts())
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: mpg, Length: 129, dtype: int64
# 4    203
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64
# 97.0     21
# 98.0     18
# 350.0    18
# 318.0    17
# 250.0    17
#          ..
# 104.0     1
# 110.0     1
# 130.0     1
# 111.0     1
# 144.0     1
# Name: displacement, Length: 82, dtype: int64
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
#        ..
# 61      1
# 93      1
# 148     1
# 152     1
# 82      1
# Name: horsepower, Length: 94, dtype: int64
# 1985    4
# 2130    4
# 2945    3
# 2265    3
# 2125    3
#        ..
# 2875    1
# 3102    1
# 3664    1
# 2807    1
# 2625    1
# Name: weight, Length: 350, dtype: int64
# 14.5    23
# 15.5    21
# 14.0    16
# 16.0    16
# 13.5    15
#         ..
# 11.1     1
# 12.1     1
# 21.9     1
# 22.1     1
# 11.6     1
# ...

# %% [markdown]
# - Cylinders and origin should be converted to qualitative data
# - year should be converted to current age (based on the year the dataset was generated)
# - Except acceleration all other features are skewed right

# %% [markdown]
# ### (f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.

# %% [markdown]
# Weight, displacement and cylinders are highly negatively correlated with mpg, but they have high correlations among themselves too. This means they are confounders, and only one of them should be used in the final model for better inference of its impact on mpg. Year and origin are moderately positively correlated with mpg, and are not correlated amongst themselves, and should be used in the model.

# %% [markdown]
# # 10. This exercise involves the Boston housing data set.

# %% [markdown]
# ### (a) To begin, load in the Boston data set, which is part of the ISLP library.

# %%
from ISLP import load_data
boston = load_data('Boston')
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %% [markdown]
# ### (b) How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
boston.shape
# Out:
# (506, 13)

# %% [markdown]
# 506 rows which represent the number of records collected and 13 columns represent the feature or stats regarding which the data was collected

# %% [markdown]
# ### (c) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
pd.plotting.scatter_matrix(boston, figsize=(16, 16))
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='zn', ylabel='crim'>,
#         <Axes: xlabel='indus', ylabel='crim'>,
#         <Axes: xlabel='chas', ylabel='crim'>,
#         <Axes: xlabel='nox', ylabel='crim'>,
#         <Axes: xlabel='rm', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='rad', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>,
#         <Axes: xlabel='ptratio', ylabel='crim'>,
#         <Axes: xlabel='lstat', ylabel='crim'>,
#         <Axes: xlabel='medv', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='zn'>,
#         <Axes: xlabel='zn', ylabel='zn'>,
#         <Axes: xlabel='indus', ylabel='zn'>,
#         <Axes: xlabel='chas', ylabel='zn'>,
#         <Axes: xlabel='nox', ylabel='zn'>,
#         <Axes: xlabel='rm', ylabel='zn'>,
#         <Axes: xlabel='age', ylabel='zn'>,
#         <Axes: xlabel='dis', ylabel='zn'>,
# ...

# %% [markdown]
# - low crime towns have larger residential land zones
# - crime rates are low for all towns except towns with around 20% industrial area
# - high property tax, less number of teachers correlate with high crime
# - crime leads to lower value of houses
# - riverside properties have larger area
# - older towns have higher nitrogen concentration, higher crime rates, and are closer to employment centers
# - poorer communities with cheaper houses are found near employment centers
# - richer communities live in pricier houses

# %% [markdown]
# ### (d) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %% [markdown]
# - low crime towns have larger residential land zones
# - crime rates are low for all towns except towns with around 20% industrial area
# - high property tax, less number of teachers correlate with high crime
# - crime leads to lower value of houses

# %% [markdown]
# ### (e) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
fig, axes = plt.subplots(1,3)
boston.crim.plot.box(ax = axes[0])
boston.tax.plot.box(ax = axes[1])
boston.ptratio.plot.box(ax = axes[2])
# Out:
# <Axes: >

# %% [markdown]
# Crime rates are usally low and have many outliers. We can consider the ones above 60 as very high. Tax and student teacher ratio don't have outliers.

# %%
boston.crim.sort_values(ascending=False)
# Out:
# 380    88.97620
# 418    73.53410
# 405    67.92080
# 410    51.13580
# 414    45.74610
#          ...
# 55      0.01311
# 341     0.01301
# 285     0.01096
# 284     0.00906
# 0       0.00632
# Name: crim, Length: 506, dtype: float64

# %% [markdown]
# suburb 380, 418, and 405 have very high crime rate (above 60)

# %%
boston.max() - boston.min()
# Out:
# crim        88.96988
# zn         100.00000
# indus       27.28000
# chas         1.00000
# nox          0.48600
# rm           5.21900
# age         97.10000
# dis         10.99690
# rad         23.00000
# tax        524.00000
# ptratio      9.40000
# lstat       36.24000
# medv        45.00000
# dtype: float64

# %% [markdown]
# - Tax has an extremely large range
# - crime, zn, and age have moderately big ranges
# - Remaining features have small ranges

# %% [markdown]
# ### (f) How many of the suburbs in this data set bound the Charles river?

# %%
boston[boston.chas == 1].count()
# Out:
# crim       35
# zn         35
# indus      35
# chas       35
# nox        35
# rm         35
# age        35
# dis        35
# rad        35
# tax        35
# ptratio    35
# lstat      35
# medv       35
# dtype: int64

# %%
boston.shape
# Out:
# (506, 13)

# %% [markdown]
# Out of 506, 35 suburbs bound Charles river

# %% [markdown]
# ### (g) What is the median pupil-teacher ratio among the towns in this data set?

# %%
boston.ptratio.median()
# Out:
# 19.05

# %% [markdown]
# ### (h) Which suburb of Boston has lowest median value of owner-occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
boston[boston.medv == boston.medv.min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# - There are two suburb 398 and 405 that have the lowest medv.
# - Crime for both are extremely high and are outliers.
# - nox, lstat is very high.
# - zn, chas, rm, dis are very low.
# - indus, tax, ptratio in near the 3rd quartile.
# - age, rad is maximum.

# %% [markdown]
# ### (i) In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.

# %%
boston[boston.rm > 7].shape
# Out:
# (64, 13)

# %%
boston[boston.rm > 8].shape
# Out:
# (13, 13)

# %%
boston[boston.rm > 8]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %%
boston[boston.rm > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# - very low crime compared to entire distribution
# - moderately low indus, dis, lstat, medv compared to entire distribution
